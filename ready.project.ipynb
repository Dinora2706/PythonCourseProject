# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("who_csv.csv")
data
# Out:
#                          Name       WHO Region  Cases - cumulative total  \
# 0                      Global              NaN                  82579768
# 1    United States of America         Americas                  19578217
# 2                       India  South-East Asia                  10305788
# 3                      Brazil         Americas                   7675973
# 4          Russian Federation           Europe                   3212637
# ..                        ...              ...                       ...
# 233                     Samoa  Western Pacific                         0
# 234                   Tokelau  Western Pacific                         0
# 235                     Tonga  Western Pacific                         0
# 236              Turkmenistan           Europe                         0
# 237                    Tuvalu  Western Pacific                         0
#
#      Cases - cumulative total per 1 million population  \
# ...

# %%
data1 = data.head(10)
data1
data2 = data.head(15)
data1
# Out:
#                        Name       WHO Region  Cases - cumulative total  \
# 0                    Global              NaN                  82579768
# 1  United States of America         Americas                  19578217
# 2                     India  South-East Asia                  10305788
# 3                    Brazil         Americas                   7675973
# 4        Russian Federation           Europe                   3212637
# 5                    France           Europe                   2595661
# 6        The United Kingdom           Europe                   2542069
# 7                     Italy           Europe                   2129376
# 8                     Spain           Europe                   1893502
# 9                   Germany           Europe                   1755351
#
#    Cases - cumulative total per 1 million population  \
# 0                                       10578.591038
# 1                                       59148.220000
# ...

# %%
grp = data.groupby("WHO Region")
x = grp["Cases - cumulative total"].agg(np.mean)
y = grp["Deaths - cumulative total"].agg(np.sum)
z = grp["Deaths - cumulative total per 1 million population"].agg(np.mean)
r = grp["Cases - newly reported in last 24 hours"].agg(np.mean)
a = grp["Cases - newly reported in last 7 days"].agg(np.mean)
b = grp["Deaths - newly reported in last 7 days"].agg(np.mean)
c = grp["Deaths - cumulative total"].agg(np.mean)
print(x)
print(y)
print(z)
print(r)
print(b)
print(c)
# Out:
# WHO Region
# Africa                   3.839806e+04
# Americas                 6.403508e+05
# Eastern Mediterranean    2.253338e+05
# Europe                   4.308612e+05
# Other                    7.450000e+02
# South-East Asia          1.093017e+06
# Western Pacific          3.158711e+04
# Name: Cases - cumulative total, dtype: float64
# WHO Region
# Africa                    42697
# Americas                 864826
# Eastern Mediterranean    121664
# Europe                   585432
# Other                        13
# South-East Asia          183999
# Western Pacific           20218
# Name: Deaths - cumulative total, dtype: int64
# WHO Region
# Africa                    38.918600
# Americas                 304.252679
# Eastern Mediterranean    185.716364
# Europe                   585.959355
# Other                           NaN
# South-East Asia           40.775455
# Western Pacific           39.089429
# Name: Deaths - cumulative total per 1 million population, dtype: float64
# ...

# %% [markdown]
# # line graph comparing cases in the last 7 days and 24 hours in WHO regions

# %%
plt.figure(figsize = (12, 5))
plt.style.use("seaborn-darkgrid")
plt.plot(a, marker = "o", markerfacecolor = "orange", linewidth = 4, alpha = 0.4, label = "last 7 days")
plt.plot(r, marker = "", color = 'red', alpha = 0.4, linewidth = 4, label = "last 24 hours")
plt.xticks(rotation = 90)
plt.title("Comparison of cases and in the last 7 days and 24 hours in WHO Regions")
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # line graph comparing cases and deaths in WHO regions

# %%
with plt.style.context('ggplot'):
    plt.figure(figsize = (12, 5))
plt.plot(x, marker = "o", markerfacecolor = "blue", linewidth = 4, label = "Cases")
plt.plot(y, marker = "", linestyle = "dashed", linewidth = 2, label = "Deaths")
plt.xticks(rotation = 90)
plt.title("Comparison of cumulative cases and deaths in WHO Regions")
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # pie chart comparing top-5 countries and the total number of cases

# %%
plt.figure(figsize = (12,5))
plt.style.use("fivethirtyeight")

slices = [11424.750000,2355.960000, 9683.880000, 4662.990000,9656.190000]
labels = ["The USA", "India", "Brazil", "Russian Federation", "The UK"]
colors = ["#008fd5", "#fc4f30", "#e5ae37", "#6d904f", "purple"]
plt.pie(slices, labels = labels, wedgeprops = {"edgecolor": "black"}, shadow = True, startangle = 90, autopct = "%1.1f%%")
plt.title("top-5 countries and the cumulative number of cases of COVID-19")
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #  pie chart comparing top-5 countries and the total number of deaths

# %%
plt.figure(figsize = (12,5))
plt.style.use("fivethirtyeight")

slices = [339550,149218, 194949 ,58002 , 74125 ]
labels = ["The USA", "India", "Brazil", "Russian Federation", "The UK"]
colors = ["#8B7D6B", "#FFEBCD", "#E3CF57", "#A52A2A", "blue"]
plt.pie(slices, labels = labels, wedgeprops = {"edgecolor": "black"}, shadow = True, startangle = 90, autopct = "%1.1f%%")
plt.title("top-5 countries and the cumulative number of deaths from COVID-19")
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # bar graph comparing deaths - newly reported in last 24 hours

# %%
who_region = ["Russian Federation", "India", "United States of America", "France", "Brazil", "The United Kingdom"]
cases = [447, 224, 3761, 158, 1074, 613]

plt.figure(figsize = (12,5))
New_colors = ['green', 'blue', 'purple','brown','teal', 'yellow']
plt.bar(who_region, cases, color = New_colors)
plt.xticks(rotation = 90)
plt.title("6 countries compared in terms of deaths - newly reported in last 24 hours", fontsize = 14)
plt.xlabel("who_region", fontsize = 14)
plt.ylabel("cases", fontsize = 14)
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # bar graph comparing deaths - cumulative total per 1 million population

# %%
x = data2["Name"]
y = data2["Deaths - cumulative total per 1 million population"]

plt.figure(figsize = (16, 5))

plt.xlabel("Name of the country", fontsize =18, color = "red")
plt.ylabel("Deaths - cumulative total per 1 million population", fontsize = 16, color = "red")
plt.title("Comparison of deaths - cumulative total per 1 million population", color = "red")
plt.xticks(rotation = 90)
plt.ticklabel_format(style = "plain")

plt.bar(x,y, color = "#273c75")
plt.show()

# %% [markdown]
# # scatter plot comparing deaths - cumulative total per 1 million population

# %%
plt.figure(figsize = (12, 5))
plt.scatter(data2["Name"], data2["Deaths - cumulative total per 1 million population"], cmap = "jet", marker = "d", alpha = 0.5)
plt.xticks(rotation = 90)
plt.title("Deaths - cumulative total per 1 million population in 15 countries")
plt.xlabel("Countries", fontsize = 18, color = "Black")
plt.ylabel("Index of cases", fontsize = 18, color = "Black")

plt.show()

# %% [markdown]
# # Bar chart showing the cases newly reported in the last week

# %%
data2.pivot( index = "Name", columns = "WHO Region", values = 'Cases - newly reported in last 7 days').plot(kind = "barh", title = "scale of COviD_19",  figsize = (12,8))

plt.ylabel("Countries")
plt.xlabel("Cases - newly reported in last 7 days")
plt.ticklabel_format(axis='y')
plt.title("Bar chart showing the cases newly reported in the last week")
plt.show()

# %% [markdown]
# # Bar chart showing the cumulative cases by countries and WHO Regions

# %%
data1.pivot( index = "Name", columns = "WHO Region", values = 'Cases - cumulative total').plot(kind = "bar", title = "scale of COviD_19",  figsize = (12,8))

plt.ylabel("Countries")
plt.xlabel("The cases - cumulative total")
plt.title("Bar chart showing the cumulative cases by countries and WHO Regions")
plt.ticklabel_format(style='plain', axis='y')

plt.show()
